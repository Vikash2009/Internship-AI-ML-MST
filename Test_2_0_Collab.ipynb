# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikash2009/Internship-AI-ML-MST-/blob/main/Test_2_0_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistics Test 1.0

# %% [markdown]
# Time - 2 Hr
#
#
# Total Marks = 60

# %%
All the best

# %% [markdown]
# # Multiple Choice Questions

# %% [markdown]
# Question 1
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A -> 1 - α
#
# B -> 1 - β
#
# C -> α
#
# B -> p

# %%
# Ans=C

# %% [markdown]
# Question 2
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Different from 25%
#
# B-> Equal to 25%
#
# C-> Less than 25%
#
# D-> More than 25%

# %%
# Ans=B

# %% [markdown]
# Question 3
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Equal in number
#
# B-> Paired
#
# C-> Correlation
#
# D-> All of the above

# %%
# Ans=C

# %% [markdown]
# Question 4
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Type-I error
#
# B-> Type-II error
#
# C-> Unbiased decision
#
# D-> Difficult to tell

# %%
# Ans=B

# %% [markdown]
# Question 5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A-> Null hypothesis
#
# B-> Statistical hypothesis
#
# C-> Research hypothesis
#
# D-> Simple hypothesis

# %%
# Ans=C

# %% [markdown]
# Question 6
#
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Decreased
#
# B-> Increased
#
# C-> Constant
#
# D-> Both (a) and (b)

# %%
# Ans=A

# %% [markdown]
# Question 7
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A-> Two-tailed test
#
# B-> Left-tailed test
#
# C-> Right-tailed test
#
# D->Neither (a), (b) and (c)

# %%
# Ans=A

# %% [markdown]
# Question 8
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Eating cheese before bed gives you more nightmares.
#
# B-> Eating cheese before bed gives you fewer nightmares.
#
# C-> Eating cheese is linearly related to the number of nightmares you have.
#
# D-> The number of nightmares you have is not affected by eating cheese before bed.

# %%
# Ans=D

# %% [markdown]
# Question 9
#
# ![image.png](data:image/png;base64,...)

# %%
A-> N

B-> n/N>5

C-> N(1-P)>5

D-> N>30

# %%
# Ans=D

# %% [markdown]
# Question 10
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Rejecting HO when HO is correct
#
# B-> Rejecting HO when H1 is correct
#
# C-> None of the options
#
# D-> Accepting HO when HO is correct

# %%
# Ans=A

# %% [markdown]
# Question 11
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> 5% of the time we will make an incorrect inference
#
# B-> 5% of the time we will say that there is a real difference when there is no difference (Type I error)
#
# C-> 95% of the time we will say that there is no difference when there is a difference (Type II error)
#
# D-> 95% of the time the null hypothesis will be correct

# %%
# Ans->D

# %% [markdown]
# Question 12
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> t-test
#
# B->z-test
#
# C-> chi-square test (also written as x2-test)
#
# D-> f-test

# %%
# ANS =B

# %% [markdown]
# Question 13
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A-> Hypothesis
#
# B-> Hypothesis testing
#
# C-> Level of significance
#
# D-> Test statistic

# %%
# Ans=A

# %% [markdown]
# Question 14
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> The probability of a type I error is controlled by the selection of the level of significance α.
#
# B-> The probability of a type II error is controlled by the sample size (n).
#
# C-> The power of a test depends upon the sample size and the distance between the null hypothesis and the alternative hypothesis.
#
# D-> The p-value measures the probability that the null hypothesis is true.

# %%
# Ans =D

# %% [markdown]
# Question 15
#
# ![image.png](data:image/png;base64,...)

# %% [raw]
# A-> Left-tailed test
#
# B-> Right-tailed test
#
# C-> Two-tailed test
#
# D-> Difficult to tell

# %%
# Ans =B

# %% [markdown]
# # Python Basic Exercise
#
# ### Solve any three

# %% [markdown]
# Que 1 -> You have a list a=[1,2,3,6,9,7,4,5,8], and you have to find the kth element from the list. This means I want to find the 2nd largest number from the list. Similarly, you have to create a function where I pass a number, say 4, and the function will return the 4th largest number from the list.

# %%
def nth_largest_num(a,n):
  sorted_list=sorted(a)
  if n<len(sorted_list):
    return sorted_list[n-1]
  else:
    return None

a = [1, 2, 3, 6, 9, 7, 4, 5, 8]
n = 4
print(f"The {n}nd largest number is: {nth_largest_num(a, n)}")
# Out:
# The 4nd largest number is: 4

# %% [markdown]
# Que 2-> you have a list [1,8,0,6,4,0,6,0,0,2,0], You need to shift all the zeros to the right , without using any inbuilt function.

# %%
Sol->

# %% [markdown]
# Que 3->Reverse a string without using any inbuilt function like slicing.

# %%
Sol-

# %% [markdown]
# Que 4-> To find common prefix in array of strings
#
# array= ['Abce','Abcjhgj','Abcf']
#
#
# The common prefix among the strings 'Abce', 'Abcjhgj', and 'Abcf' is 'Abc'. So, the common prefix is 'Abc'.

# %%
Sol->

# %% [markdown]
# Que 5- Given the list l = [1,2,0,1,2,0,0], I want the output to be ans = [0,0,0,2,2,1,1] without using any inbuilt function

# %%
Sol->

# %% [markdown]
# # Statistics Theory Question
#
# ### Any 4

# %% [markdown]
# Que 1- What is Central Limit Theoram ? Explain.

# %% [markdown]
# ANs- `Central Limit Theoram(CLT)` states that whenever we withdraw samples from a given popultion the sample will be always `normally distributed(bell curve)` will be formed regardless of the population distribution.
# the standard number of observation in a sample should be `> 30(greator)`, because its a a very minimal chance of showing any random distribution as long as samples are drawn randomly and independently. its one of the fundamental steps in `inferential statistics`.

# %% [markdown]
# Que 2- What is CDF(Comulative density function). Explain with mathematics.

# %% [markdown]
# Ans- in `CDF(Cumultaive density function)` we find the probability of something happening within a range of given intervals. we always consider the values from lower to upper range excluding the upper value.
# F(x)=P(X≤x)
# by plotting the CDF we can actually find the probality of any random variable for any specific ranges.

# %% [markdown]
# Que 3- What is Anova test. how we can calculate behind the scene ?

# %%
Ans=

# %% [markdown]
# Que 4-  What is Chi-Square test. how we will calculate behind the scene.

# %%
Ans=

# %% [markdown]
# Que 5-  What is the difference between inferential and descriptive statistics.

# %% [markdown]
# **Descriptive stats:**
# *   we perform various mathematics on the whole population/data set.
# *   its used to describe and summarise the whole data.
# *   bascically its of 2 types:
#     1.   measure of central tendency(mean,median,mode)
#     2.   measure of dispersion(variance,standard deviation)
# *   eg-calculating average height of MST AI/ML batch.
#
# **infernetial stats:**
#
#
# *   we withdraw some samples from the whole population and then perform some mathematical operations and find the measures of the whole population based on the results of the samples
# *   inferential statistics are used to test hypotheses, estimate parameters, and make predictions.
# * types:
#   1.   hypothesis testing
#   2.   confidence intervals
# *eg- finding average weight of whole population of india

# %% [markdown]
# Que 6- Explain any 2 distribution.

# %% [markdown]
# **1-Normal Distribution:**
#
#
# *   the normal distribution is a symmetric, bell-shaped probability distribution that is characterized by its mean (
# μ) and standard deviation (σ).
# *   the normal distribution is often used to model natural phenomena such as heights, weights, test scores, and errors in measurements.
#
# **2- Bionomial distribution**
# * The binomial distribution is a discrete probability distribution that describes the number of successes in a fixed number of independent Bernoulli trials (experiments with two possible outcomes: success or failure), each with the same probability of success (p).
# * The binomial distribution is commonly used in scenarios such as flipping a coin multiple times, where each flip is a Bernoulli trial with a 50% chance of success, or in quality control to determine the likelihood of a certain number of defective items in a sample.

# %% [markdown]
# # Statistics Mathematics  Question
#
# ## Any 2

# %% [markdown]
# Que 1 - if I generate heights for 1000 people from a normal distribution, what would be the probability for a new person to have a height of 70 inches using (CDF) then z-score table? take height in inches.
#
# #### Mean height (in inches) of the population
# mean_height = 66
#
# #### Standard deviation of heights (in inches) of the population
# std_dev_height = 3
#
#
# ##### Generate data using this code
# ###### Generate heights for 1000 people from a normal distribution
# heights = np.random.normal(mean_height, std_dev_height, 1000)))

# %%
import numpy as np
import scipy.stats as st

# %%
new_height=70
mean_height=66
std=3

# %%
# std of population diya hua hai so hmlog z test use krenge

# %%
Z=(new_height-mean_height)/std

# %%
prob=st.norm.cdf(Z)
print(prob)
# Out:
# 0.9087887802741321

# %% [markdown]
# Que 2-  Suppose a fitness center manager anticipates the attendance for a particular yoga class throughout the week. Based on historical data and other factors, they estimate the expected attendance in numbers:
#
# ### Expected Attendance:
#
# Monday: 40
#
# Tuesday: 45
#
# Wednesday: 38
#
# Thursday: 50
#
# Friday: 55
#
# Saturday: 60
#
# Sunday: 65
#
# However, after the week concludes, the actual attendance is recorded:
#
#
#
# ### Observed (Actual) Attendance:
#
#
#
# Monday: 38
#
# Tuesday: 43
#
# Wednesday: 40
#
# Thursday: 48
#
# Friday: 52
#
# Saturday: 58
#
# Sunday: 62
#
# Ho: There is no significant difference between the expected and observed attendance for the yoga class throughout the week.
#
# Ha: There is a significant difference between the expected and observed attendance for the yoga class throughout the week.
#
# #### Use chi-square test *Statistical Tools*

# %%
Sol=

# %% [markdown]
# Que3 -> Calculate anova test
#
#
#
#
#
#     | Student_ID | Semester | Total_Marks |
#     |------------|----------|-------------|
#     | 1          | Fall     | 85          |
#     | 2          | Fall     | 78          |
#     | 3          | Fall     | 92          |
#     | 4          | Spring   | 88          |
#     | 5          | Spring   | 75          |
#     | 6          | Spring   | 82          |
#     | 7          | Summer   | 90          |
#     | 8          | Summer   | 86          |
#     | 9          | Summer   | 79          |
#
#
# Null Hypothesis (Ho): The average marks of students in each semester are approximately equal.
#
# Alternative Hypothesis (Ha): The average marks of students in at least one semester are different.

# %%
import pandas as pd

data = {
    'Student_ID': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'Semester': ['Fall', 'Fall', 'Fall', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer'],
    'Total_Marks': [85, 78, 92, 88, 75, 82, 90, 86, 79]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Student_ID Semester  Total_Marks
# 0           1     Fall           85
# 1           2     Fall           78
# 2           3     Fall           92
# 3           4   Spring           88
# 4           5   Spring           75
# 5           6   Spring           82
# 6           7   Summer           90
# 7           8   Summer           86
# 8           9   Summer           79

# %%
import pandas as pd
from scipy.stats import f_oneway

# %%
f_statistic, p_value = f_oneway(df[df['Semester'] == 'Fall']['Total_Marks'],
                                df[df['Semester'] == 'Spring']['Total_Marks'],
                                df[df['Semester'] == 'Summer']['Total_Marks'])

# %%
print("F-Statistic:", f_statistic)
print("P-Value:", p_value)
# Out:
# F-Statistic: 0.2724795640326976
# P-Value: 0.7704295549801264

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The average marks of students in at least one semester are different.")
else:
    print("Fail to reject the null hypothesis: The average marks of students in each semester are approximately equal.")
# Out:
# Fail to reject the null hypothesis: The average marks of students in each semester are approximately equal.
